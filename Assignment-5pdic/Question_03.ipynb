# %%
#  3) Write a Python program to check whether a specific element exists inside a tuple using the in keyword

# %%
tup=(40,15,12,63,48,7,8,90,400)

element=int(input("Enter elemnt to search : "))

if element in tup:
    print(element, "exists in the tuple.")
else:
    print(element, "does not exist in the tuple.")
# Out:
# 25 does not exist in the tuple.
