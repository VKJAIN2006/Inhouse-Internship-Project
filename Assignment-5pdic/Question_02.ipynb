# %%
#  2) Write a Python program to join three separate tuples into one new tuple using the + operator.

# %%
tup1=(1,2,3,4)
tup2=(5,68,7,9,10)
tup3=(52,1,2,30,25)

tup4=tup1+tup2+tup3
print(tup4)
# Out:
# (1, 2, 3, 4, 5, 68, 7, 9, 10, 52, 1, 2, 30, 25)
