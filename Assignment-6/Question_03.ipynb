# %%
# 3) Search for more free API's generate your and call them to fetch data. Display some data in your program.

import requests

def random_joke():

    url = "https://official-joke-api.appspot.com/random_joke"

    try:

        # Send request to API
        response = requests.get(url)

        # Raise error if request fails
        response.raise_for_status()

        # Convert response into JSON
        data = response.json()

        # Display joke data
        print("\n😂 Random Joke 😂\n")

        print("Setup :", data['setup'])

        print("Punchline :", data['punchline'])

    except requests.exceptions.RequestException as e:

        print("Error :", e)


# Function Call
random_joke()
# Out:
# 😂 Random Joke 😂
#
# Setup : If you're American when you go into the bathroom, and American when you come out, what are you when you're in there?
# Punchline : European

# %%
import requests

def get_quotes():

    url = "https://api.api-ninjas.com/v2/quotes?categories=success,wisdom"

    headers = {
        "X-Api-Key": "V2367dFEUspfxWyz9Yv8sA7YFzwqbIq5s9TCGDkX"
    }

    try:

        # Send GET request
        response = requests.get(url, headers=headers)

        # Raise error if request fails
        response.raise_for_status()

        # Convert JSON response
        data = response.json()

        # Display quote data
        print("\n🌟 Motivational Quote 🌟\n")

        for quote in data:

            print("Quote :", quote['quote'])

            print("Author :", quote['author'])

            print("Category :", quote['categories'])

    except requests.exceptions.RequestException as e:

        print("Error :", e)


# Function Call
get_quotes()
# Out:
# 🌟 Motivational Quote 🌟
#
# Quote : The road to success begins with knowing what you need to know and why
# Author : Savania China
# Category : ['success', 'wisdom', 'inspirational']
